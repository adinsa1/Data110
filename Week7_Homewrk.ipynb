# %% [markdown]
# <a href="https://colab.research.google.com/github/adinsa1/Data110/blob/main/Week7_Homewrk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assefa Dinsa Dassa
#
# Professor Muhammad
#
# Data110 - Week7 Homework
#
# 14 March 2024

# %%
# 1. Data Import and Exploration:
## 1.1 Load Libraries:
## 1.1.1 Import seaborn to load the penguins dataset and carry out data visualization
import seaborn as sns

## 1.1.2 Import matplotlib.pyplot to be able to  create  statistic, and interactive, visualizations in Python
import matplotlib.pyplot as plt

## 1.1.3 Import pandas for data manipulation and analysis
import pandas as pd

# %%
## 1.2 Load the penguins dataset using seaborn's load_dataset function
penguins = sns.load_dataset("penguins")


## 1.2.1 Display the first 10 rows of the dataframe to be able to understand the structure of the dataset:
(penguins.head(10))
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# ...

# %%
## 1.2.2 Use the .describe() method to get a statistical summary of the numerical columns in the dataset:
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
## 1.2.3 Find out info on Columns
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# 2. Data Filtering
## 2.1 Filter the dataset to include only those penguins with a body mass greater than 4000 grams. Store this subset in a new DataFrame and display the first 5 rows
X = penguins[penguins['body_mass_g']>4000]
X.head(5)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g   sex
# 7        4675.0  Male
# 9        4250.0   NaN
# 14       4400.0  Male
# 17       4500.0  Male
# 19       4200.0  Male

# %%
# 3. Conditional Filtering:
## 3.1 Create a subset of the data where the penguin's bill length is between 40 mm and 50 mm, and the bill depth is less than 18 mm.
X = penguins[penguins['bill_depth_mm'] <18]
X.head()
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
#
#     body_mass_g     sex
# 1        3800.0  Female
# 6        3625.0  Female
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female

# %%
x = penguins[~(penguins['bill_length_mm'] >40) & (penguins['bill_depth_mm'] <50)]
x.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female

# %%
# 4. Data Grouping and Aggregation:

## 4.1 Group the dataset by species and island, and calculate the average flipper_length_mm for each group. Sort the results in descending order of flipper lengt#


# Select data by species, island and flipper_length_mm:
penguins_selected = penguins[['species', 'island', 'flipper_length_mm' ]]

# Display the first few rows to verify the new column

print(penguins_selected.head())
# Out:
#   species     island  flipper_length_mm
# 0  Adelie  Torgersen              181.0
# 1  Adelie  Torgersen              186.0
# 2  Adelie  Torgersen              195.0
# 3  Adelie  Torgersen                NaN
# 4  Adelie  Torgersen              193.0

# %%
Y= penguins[penguins['species']=='Adelie']
G=penguins[penguins['species']=='Gentoo']
C=penguins[penguins['species']=="Chinstrap"]
C.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count       68.000000      68.000000          68.000000    68.000000
# mean        48.833824      18.420588         195.823529  3733.088235
# std          3.339256       1.135395           7.131894   384.335081
# min         40.900000      16.400000         178.000000  2700.000000
# 25%         46.350000      17.500000         191.000000  3487.500000
# 50%         49.550000      18.450000         196.000000  3700.000000
# 75%         51.075000      19.400000         201.000000  3950.000000
# max         58.000000      20.800000         212.000000  4800.000000

# %%
# 4.2 Access flipper_length_mm to carry out calculation of average length"

# %%
# penguins average flipper_length_mm in decsending order:

Gentoo------------ 257.19mm
Chinstrap--------- 195.82mm
Adelie------------ 189.85mm
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
## 5. Advanced Visualization:

# 5.1 Create a histogram to visualize the distribution of penguin body masses. Use different colors to differentiate between the species. Ensure your histogram is clearly labeled with a title, x-axis and y-axis labels, and a legend.
## Load the penguins dataset from seaborn


# Plot each speciesonly penguins of the current 'species'

plt.hist(Y['body_mass_g'],color='green',label='Adelie')
plt.hist(G['body_mass_g'],color='gray',label='Gentoo')
plt.hist(C['body_mass_g'],color='red',label='Chinstrap')
plt.xlabel('Specieis)')
plt.ylabel('Body_mass_g)')
plt.legend(title='Species')
plt.show()

# %%
## 6.
# List of colors you want to use

colors = ['red', 'green', 'blue']
unique_species = penguins['species'].unique()

for species, color in zip(unique_species, colors):

	subset = penguins[penguins['species'] == species]

	plt.hist(subset['flipper_length_mm'], color=color, label=species)
