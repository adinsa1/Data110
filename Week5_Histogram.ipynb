# %% [markdown]
# <a href="https://colab.research.google.com/github/adinsa1/Data110/blob/main/Week5_Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/adinsa1/Data110-32213/main/dataset/titanic.csv')
# The first 5 lines
df.head()
# Out:
#   class    age     sex  survived
# 0   1st  29.00  female  survived
# 1   1st   2.00  female      died
# 2   1st  30.00    male      died
# 3   1st  25.00  female      died
# 4   1st   0.92    male  survived

# %%
# The last 5 lines
df.tail()
# Out:
#     class   age   sex survived
# 751   3rd  27.0  male     died
# 752   3rd  26.0  male     died
# 753   3rd  22.0  male     died
# 754   3rd  24.0  male     died
# 755   3rd  29.0  male     died

# %%
#find out mean, count etc
df.describe()
# Out:
#               age
# count  756.000000
# mean    30.397989
# std     14.259049
# min      0.170000
# 25%     21.000000
# 50%     28.000000
# 75%     39.000000
# max     71.000000

# %%
# Number of Columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   class     756 non-null    object
#  1   age       756 non-null    float64
#  2   sex       756 non-null    object
#  3   survived  756 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 23.8+ KB

# %%
# Draw Histogram (Age)
plt.hist(df['age'])
plt.show()

# %%
# Show graph with length of interval, bins = 1
plt.hist(df['age'], bins=1)
plt.show()

# %%
# Show graph wit bins = 20 and edgecolor = black
plt.hist(df['age'], bins=20, edgecolor='black')
plt.show()

# %%
# Edgecolor , white
plt.hist(df['age'], bins=20, edgecolor='white')
plt.figure(figsize=(10,6))
plt.show()

# %%
# use ggplot
plt.hist(df['age'], edgecolor='white')
plt.figure(figsize=(10,6))
plt.style.use('ggplot')
plt.show()

# %%
# add new xticks
plt.hist(df['age'])
plt.xticks([0,20,40,60])
plt.show()

# %%
# The entire graph
plt.style.use('ggplot')
plt.figure(figsize = (10, 6))
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='white')
plt.title('Age Distribution of Titanic Passengers')
plt.xlabel('Age in Year')
plt.ylabel('Count')
plt.grid(axis='x')
plt.xticks([0,20,40,60])
plt.tick_params(axis='x', colors = 'gray')
plt.show()

# %%
# Kernel Density Estimate (KDE) Graph
sns.kdeplot(df['age'])
plt.show()

# %%
# With fill added to
sns.kdeplot(df['age'],fill=True)
plt.show()

# %%
# With alpha added
plt.figure(figsize=(10,6))
sns.kdeplot(df['age'], bw_adjust=2, fill=True, alpha=0.8)
plt.title('Kernel Density Estimate of Age Distribution of Titanic Passengers')
plt.xlabel('Age in Year')
plt.ylabel('Density')
plt.show()

# %%
# Age by Sex
df.head()
# Out:
#   class    age     sex  survived
# 0   1st  29.00  female  survived
# 1   1st   2.00  female      died
# 2   1st  30.00    male      died
# 3   1st  25.00  female      died
# 4   1st   0.92    male  survived

# %%
age_male=df[df['sex']=='male'] ['age']
age_female=df[df['sex']=='female'] ['age']
plt.figure(figsize=(10,6))
plt.hist([age_male, age_female])
plt.title('Age Distribution of Titanic Passengers by Sex')
plt.legend()
plt.xlabel('Age')
plt.ylabel('count')
plt.xticks([0,20,40,60])
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
