# %% [markdown]
# <a href="https://colab.research.google.com/github/adinsa1/Data110/blob/main/Assefa_Data110Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load Dataset
df = pd.read_csv('https://raw.githubusercontent.com/adinsa1/Data110/main/Dataset/life_exp_kaggle_full.csv')

# %%
# View Pertinent Information About the DataFrame;
# View the First Five Lines of the DataFrame;

df.head()
# Out:
#            Country Name Country Code                      Region  \
# 0           Afghanistan          AFG                  South Asia
# 1                Angola          AGO          Sub-Saharan Africa
# 2               Albania          ALB       Europe & Central Asia
# 3               Andorra          AND       Europe & Central Asia
# 4  United Arab Emirates          ARE  Middle East & North Africa
#
#            IncomeGroup  Year  Life Expectancy World Bank  \
# 0           Low income  2001                      56.308
# 1  Lower middle income  2001                      47.059
# 2  Upper middle income  2001                      74.288
# 3          High income  2001                         NaN
# 4          High income  2001                      74.544
#
#    Prevelance of Undernourishment      CO2  Health Expenditure %  \
# 0                            47.8    730.0                   NaN
# 1                            67.5  15960.0              4.483516
# ...

# %%
# View the Last Five Lines of the DataFrame:

df.tail()
# Out:
#       Country Name Country Code               Region          IncomeGroup  \
# 3301       Vanuatu          VUT  East Asia & Pacific  Lower middle income
# 3302         Samoa          WSM  East Asia & Pacific  Lower middle income
# 3303  South Africa          ZAF   Sub-Saharan Africa  Upper middle income
# 3304        Zambia          ZMB   Sub-Saharan Africa           Low income
# 3305      Zimbabwe          ZWE   Sub-Saharan Africa  Lower middle income
#
#       Year  Life Expectancy World Bank  Prevelance of Undernourishment  \
# 3301  2019                      70.474                            12.4
# 3302  2019                      73.321                             4.4
# 3303  2019                      64.131                             6.3
# 3304  2019                      63.886                             NaN
# 3305  2019                      61.490                             NaN
#
#                 CO2  Health Expenditure %  Education Expenditure %  \
# ...

# %%
# View the Number and Type of the Columns:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3306 entries, 0 to 3305
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country Name                    3306 non-null   object
#  1   Country Code                    3306 non-null   object
#  2   Region                          3306 non-null   object
#  3   IncomeGroup                     3306 non-null   object
#  4   Year                            3306 non-null   int64
#  5   Life Expectancy World Bank      3118 non-null   float64
#  6   Prevelance of Undernourishment  2622 non-null   float64
#  7   CO2                             3154 non-null   float64
#  8   Health Expenditure %            3126 non-null   float64
#  9   Education Expenditure %         2216 non-null   float64
#  10  Unemployment                    3002 non-null   float64
#  11  Corruption                      975 non-null    float64
# ...

# %%
# Missing Values
df.isna().sum()
# Out:
# Country Name                         0
# Country Code                         0
# Region                               0
# IncomeGroup                          0
# Year                                 0
# Life Expectancy World Bank         188
# Prevelance of Undernourishment     684
# CO2                                152
# Health Expenditure %               180
# Education Expenditure %           1090
# Unemployment                       304
# Corruption                        2331
# Sanitation                        1247
# Injuries                             0
# Communicable                         0
# NonCommunicable                      0
# dtype: int64

# %%
# Out come After Dropping Missing Values
df = df.dropna()
df.shape
# Out:
# (286, 16)

# %%
# Descriptive Statistics of the Dataset:
df.describe()
# Out:
#               Year  Life Expectancy World Bank  \
# count   286.000000                  286.000000
# mean   2012.132867                   62.731213
# std       4.188100                    7.891594
# min    2005.000000                   42.595000
# 25%    2009.000000                   57.204250
# 50%    2012.000000                   64.489500
# 75%    2016.000000                   69.041500
# max    2019.000000                   75.423000
#
#        Prevelance of Undernourishment           CO2  Health Expenditure %  \
# count                      286.000000  2.860000e+02            286.000000
# mean                        17.285315  4.685650e+04              5.573766
# std                         11.349454  2.514654e+05              2.623721
# min                          2.500000  8.000000e+01              1.938809
# 25%                          7.800000  8.675000e+02              3.901997
# 50%                         14.700000  4.290000e+03              4.668022
# ...

# %%
# Correlation Between the Variables
# Undernourishment vs Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Prevelance of Undernourishment", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Prevelance of Undernourishment", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Prevelance of Undernourishment and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Life Expectancy and CO2

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "CO2", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "CO2", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen CO2 and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Health Expenditure and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Health Expenditure %", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Health Expenditure %", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Health Expenditure % and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Education Expenditure and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Education Expenditure %", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Education Expenditure %", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Education Expenditure and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Unemployment and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Unemployment", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Unemployment", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Unemployment and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Corruption and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Corruption", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Corruption", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Corruption and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Santation and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Sanitation", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Sanitation", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Sanitation and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Injuries and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Injuries", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Injuries", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Injuries and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Communicable Diseases and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "Communicable", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "Communicable", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen Cmmunicable Diseases and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Correlation Between Noncommunicable and Life Expectancy

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x = "NonCommunicable", y = "Life Expectancy World Bank", color='blue')
sns.regplot(data=df, x = "NonCommunicable", y = "Life Expectancy World Bank", scatter=False, color='orange')
plt.title('Correlation Beteen NonCommunicable and Life Expectancy World Bank')
plt.grid(True)
plt.show()

# %%
# Bar Graph - Undernourishment vs Life Expetancy
plt.figure(figsize=(10, 8))
sorted_df = df.sort_values(by='Prevelance of Undernourishment',ascending=False)
plt.bar(sorted_df['Prevelance of Undernourishment'],sorted_df['Life Expectancy World Bank'], color = 'green')
plt.title('Undernourishment and Life Expectancy', color = 'red')
plt.xlabel('Prevelance of Undernourishment', color = 'red')
plt.ylabel('Life Expectancy', color = 'red')
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()

# %%
# Bar Graph - CO2 vs Life Expectancy
plt.figure(figsize=(15, 6))
plt.bar(df['Health Expenditure %'],df['Life Expectancy World Bank'], edgecolor='white')
plt.title('Health Expenditure vs Life Expectancy', color = 'red')
plt.xlabel('Health Expenditure', color = 'red')
plt.ylabel('Life Expectancy', color = 'red')
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()

# %%
#
plt.figure(figsize=(12,10))
sorted_df = df.sort_values(by='Health Expenditure %')
plt.plot(df['CO2'],df['Life Expectancy World Bank'], color = 'pink')
plt.title('CO2 vs Life Expectancy', color = 'red')
plt.xlabel('CO2', color = 'red')
plt.ylabel('Life Expectancy', color = 'red')
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()
