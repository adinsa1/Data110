# %% [markdown]
# <a href="https://colab.research.google.com/github/adinsa1/Data110/blob/main/DinsaDassaData201Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Team2:Adi, Assefa, Nandini, Xutong and Yoseph
#
# Professor Abdirisak Mohamed
#
# Data201 - Project One
#
# 26 March 2024
#
# # 1. Introduction
#
#       The Project is one of the requirements of DATA203. We are handling the Project in groups. The members are, alphbetically, Adi, Assefa, Nandini, Xutong and Yoseph.
#
#
# # 2. Project Title: US CONTAGIOUS DISEASES
#
# # 3. Purpose of the Project:
#      3.1 Indentify appropriate dataset
#      3.2 Import the dataset
#      3.3 Carry out Exploratory Data Analysis
#      3.4 Find out any unique condition
#      3.5 Conduct deep analysis
#      3.6 Finding and recommendations

# %% [markdown]
# # 4. Data Source:
# https://raw.githubusercontent.com/yosephhabtu/US-Contagious-Diseases/main/us_contagious_diseases.csv

# %%
# Load libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df=pd.read_csv('https://raw.githubusercontent.com/yosephhabtu/US-Contagious-Diseases/main/us_contagious_diseases.csv')

# %%
# Summary of the First Five Lines of the Data
df.head(5)
# Out:
#        disease    state  year  weeks_reporting  count  population
# 0  Hepatitis A  Alabama  1966               50    321   3345787.0
# 1  Hepatitis A  Alabama  1967               49    291   3364130.0
# 2  Hepatitis A  Alabama  1968               52    314   3386068.0
# 3  Hepatitis A  Alabama  1969               49    380   3412450.0
# 4  Hepatitis A  Alabama  1970               51    413   3444165.0

# %%
#Summary of the Last Five Lines ofthe Data
df.tail()
# Out:
#         disease    state  year  weeks_reporting  count  population
# 18865  Smallpox  Wyoming  1949                0      0    285544.0
# 18866  Smallpox  Wyoming  1950                1      2    290529.0
# 18867  Smallpox  Wyoming  1951                1      1    295744.0
# 18868  Smallpox  Wyoming  1952                1      1    301083.0
# 18869  Smallpox  Wyoming  1953                0      0    306410.0

# %%
# Information on Count of the Data
df.count()
# Out:
# disease            18870
# state              18870
# year               18870
# weeks_reporting    18870
# count              18870
# population         18666
# dtype: int64

# %%
# Column Details
df.columns
# Out:
# Index(['disease', 'state', 'year', 'weeks_reporting', 'count', 'population'], dtype='object')

# %%
# Statistical Characterstic of the data
df.describe()
# Out:
#                year  weeks_reporting          count    population
# count  18870.000000     18870.000000   18870.000000  1.866600e+04
# mean    1974.100000        33.281558    1367.530578  4.242911e+06
# std       21.776419        20.105653    5506.530241  4.804728e+06
# min     1928.000000         0.000000       0.000000  8.685300e+04
# 25%     1956.000000        14.000000       1.000000  1.046542e+06
# 50%     1977.000000        44.000000      47.000000  2.824918e+06
# 75%     1992.000000        50.000000     440.750000  5.153640e+06
# max     2011.000000        52.000000  132342.000000  3.760752e+07

# %%
# Bar Graph of Total Household Debt by Period
plt.figure(figsize=(10, 6))
sorted_df = df.sort_values(by='year')
plt.bar(sorted_df['year'],sorted_df['disease'], color = 'green')
plt.title('US CONTAGIOUS DISEASE BY YEAR', color = 'red')
plt.xlabel('YEAR', color = 'red')
plt.ylabel('TYPE OF DISEASE', color = 'red')
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()
